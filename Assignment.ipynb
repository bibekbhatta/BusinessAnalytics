# %% [markdown]
# # Your assignment should run on this page #

# %% [markdown]
# ## Please make sure that the code runs properly ##

# %%
# installing required packages
# !pip install statsmodels==0.14.4 scikit-learn==1.5.2 pyarrow==18.0.0 # CAREFUL!!! when installingn in local machine,
