# %% [markdown]
# # Open one csv file

# %%
import pandas as pd

# %%
df = pd.read_csv('./DataFile/SameCol1.csv')

# %%
df
# Out:
#   name address  phone
# 0    a     USA      5
# 1    b      UK      4
# 2    c     CAN      3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     3 non-null      object
#  1   address  3 non-null      object
#  2   phone    3 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 200.0+ bytes

# %%
df.describe() # for summary statistics of numerical value columns only
# Out:
#        phone
# count    3.0
# mean     4.0
# std      1.0
# min      3.0
# 25%      3.5
# 50%      4.0
# 75%      4.5
# max      5.0

# %% [markdown]
# # Open one text file

# %%
path = './DataFile' #path to the file

# %%
path
# Out:
# './DataFile'

# %%
###reading one text file
with open(path+'/Test2.txt',"r") as file:
    text_test = file.read()
    file.close() # to close the file

# %%
text_test
# Out:
# '1) Is Belfast a good place for testing? This test has to be checked.\n\n2) Test will be carried out soon!\n\n3) This is to just to check.\n\nit might cost £25.00\n\nthis amounts to hypocrysy.\n\nhigh quality goods will be given\n\nuseful in belfast or not useful?'

# %% [markdown]
# # To access multiple text files

# %%
import glob
import os

# %%
path = './DataFile'

# %%
file_list = glob.glob(path+"/*.txt")

# %%
file_list
# Out:
# ['./DataFile/Test1.txt', './DataFile/Test2.txt', './DataFile/Test3.txt']

# %%
corpus = []

# %%
for file_path in file_list:
    with open(file_path, encoding="utf8") as f_input:
        corpus.append(f_input.read())

# %%
corpus
# Out:
# ['This is to test. on 16/10/2022\n\n\n2) Test data for the purpose of testing.\n\n3) Is it useful? This is belfast.\n\nthis amounts to high volumem of sales.\n\nhigh quality goods will be expected. \n                  goods are expected from China.',
#  '1) Is Belfast a good place for testing? This test has to be checked.\n\n2) Test will be carried out soon!\n\n3) This is to just to check.\n\nit might cost £25.00\n\nthis amounts to hypocrysy.\n\nhigh quality goods will be given\n\nuseful in belfast or not useful?',
#  'When will the documents be checked???? This does not look normal for testing.\n\n\n\n\n\n\n\n\nTest has to be carried out soon as suggested by everyone on the team!!!\n\n\t\t\tThis will help to check if testing is .\n\nthis amounts to $50.\n\nhigh quality goods will be provided']

# %%
import pandas as pd

# %%
df = pd.DataFrame(file_list, columns=['Filenames'])

# %%
df
# Out:
#               Filenames
# 0  ./DataFile/Test1.txt
# 1  ./DataFile/Test2.txt
# 2  ./DataFile/Test3.txt

# %%
df["Content"] = pd.DataFrame(corpus)

# %%
df.head(3)
# Out:
#               Filenames                                            Content
# 0  ./DataFile/Test1.txt  This is to test. on 16/10/2022\n\n\n2) Test da...
# 1  ./DataFile/Test2.txt  1) Is Belfast a good place for testing? This t...
# 2  ./DataFile/Test3.txt  When will the documents be checked???? This do...

# %%
#save file as csv
df.to_csv('Text_combined.csv', index=False) # check if a file names Text_combined.csv is saved on the left pane

# %% [markdown]
# # Open multiple csv files

# %%
import pandas as pd
import glob

# %%
path = './DataFile'

# %%
file_list = glob.glob(path+"/*.csv")

# %%
file_list
# Out:
# ['./DataFile/SameCol2.csv',
#  './DataFile/SameCol3.csv',
#  './DataFile/SameCol1.csv']

# %%
df = pd.concat(map(pd.read_csv, file_list))

# %%
df
# Out:
#   name address  phone
# 0    d     Nep      7
# 1    e      Ch      8
# 2    f     Rus      9
# 0    g     Ukr     10
# 1    h     Mal     11
# 2    f     Rus      9
# 0    a     USA      5
# 1    b      UK      4
# 2    c     CAN      3

# %%
#save file as csv
df.to_csv('CSV_combined.csv', index=False) # check if a file names CSV_combined.csv is saved on the left pane

# %% [markdown]
# # Open json files

# %%
import json

# %%
path = './DataFile'

# %%
File = path+'/matches_England.json'

# %%
File
# Out:
# './DataFile/matches_England.json'

# %%
with open(File,'r') as f:
    data = json.loads(f.read())

# %%
#print(json.dumps(data, indent = 4, sort_keys=True)) ## only use in a desktop environment

# %%
data[1]["venue"] # let us explore some of the data within the json file
# Out:
# 'Selhurst Park'

# %%
data[4]["venue"]
# Out:
# 'Old Trafford'

# %%
data[4]["referees"]
# Out:
# [{'refereeId': 381853, 'role': 'referee'},
#  {'refereeId': 386732, 'role': 'firstAssistant'},
#  {'refereeId': 393151, 'role': 'secondAssistant'},
#  {'refereeId': 385915, 'role': 'fourthOfficial'}]

# %%
data[4]["referees"][2]
# Out:
# {'refereeId': 393151, 'role': 'secondAssistant'}

# %%
data[4]["referees"][2]["refereeId"]
# Out:
# 393151

# %%
data[4]["referees"][2]["role"]
# Out:
# 'secondAssistant'

# %% [markdown]
# # Access one pdf file

# %%
path = './DataFile'

# %%
## we are using PyPDF2 package in this case; many other alternatives are available; e.g tika
! pip3 install PyPDF2 #if you are using Anaconda, install it differently without using pip
# Out:
# Collecting PyPDF2
#   Downloading PyPDF2-2.11.1-py3-none-any.whl (220 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.4/220.4 kB 5.5 MB/s eta 0:00:0000:01
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from PyPDF2) (4.4.0)
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-2.11.1

# %%
import PyPDF2 
# creating a pdf file object 
pdfFileObj = open(path+"/Microsoft 2021 Annual Report.pdf", "rb")

# %%
# creating a pdf reader object 
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

# %%
# creating a page object 
pageObj = pdfReader.getPage(0) 
print(pageObj.extractText())     
# extracting text from the first (0) page
# Out:
# Home
# Shareholder Letter
# Financial R eview
# Business
# General
# Human Capital R esources
# Operating Segments
# Operations
# Research & Development
# Distribution, Sales & Marketing
# Licensing Options
# Customers
# Available Information
# Discussion & Analysis
# Market Risk
# Income S tatements
# Balance Sheets
# Cash Flows S tatements
# Stockholders' Equity
# Notes
# Accounting P olicies
# Earnings P er Share
# Other Income (Expense), Net
# Investments
# Derivatives
# Inventories
# Property and Equipment
# Business Combinations
# Goodwill
# Intangible Assets
# Debt
# Income T axes
# Unearned R evenue
# Leases
# Contingencies
# Stockholders' Equity
# Accumulated Other Comprehensive Income (Loss)
# Employee S tock and Savings Plans
# Segment Information & Geo Data
# Auditor's R eport
# Controls & Procedures
# Directors & Officers
# Investor R elations
# Annual R eport 2021
# Continue to Shareholder LetterAnnual R epor t 2021
# home

# %%
## access data from all pages 
# printing number of pages in pdf file 
print(pdfReader.numPages) 
all_page = pdfReader.numPages  
#all_page
# Out:
# 67

# %%
for pages in range(all_page):
    #print(pages)
    pageObj = pdfReader.getPage(pages) 
    #print(pageObj.extractText()) # uncomment if all pages need to be printed below

# %%
# closing the pdf file object 
pdfFileObj.close()

# %% [markdown]
# # Accessing image

# %%
#! pip3 install opencv-python #if you are using Anaconda, install it differently without using pip

# %%
import cv2

# %%
path = './DataFile' #path to the file

# %%
import os

# %%
os.chdir(path)

# %%
image = cv2.imread("Test_image.png")

# %%
image[0][0]
# Out:
# array([157, 133, 102], dtype=uint8)

# %% [markdown]
# # Accessing web page

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "http://books.toscrape.com/catalogue/category/books/travel_2/index.html"

# %%
response = requests.get(url) # getting the information from webpage

# %%
soup = BeautifulSoup(response.content, "html.parser") # parsing the extracted text to get required information

# %%
titles = soup.find_all('h3') # find title

# %%
prices = soup.find_all('p', class_='price_color') #find price

# %%
stocks = soup.find_all('p', class_='instock availability') #find availability

# %%
titles # title.get_text()
# Out:
# [<h3><a href="../../../its-only-the-himalayas_981/index.html" title="It's Only the Himalayas">It's Only the Himalayas</a></h3>,
#  <h3><a href="../../../full-moon-over-noahs-ark-an-odyssey-to-mount-ararat-and-beyond_811/index.html" title="Full Moon over Noah’s Ark: An Odyssey to Mount Ararat and Beyond">Full Moon over Noah’s ...</a></h3>,
#  <h3><a href="../../../see-america-a-celebration-of-our-national-parks-treasured-sites_732/index.html" title="See America: A Celebration of Our National Parks &amp; Treasured Sites">See America: A Celebration ...</a></h3>,
#  <h3><a href="../../../vagabonding-an-uncommon-guide-to-the-art-of-long-term-world-travel_552/index.html" title="Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel">Vagabonding: An Uncommon Guide ...</a></h3>,
#  <h3><a href="../../../under-the-tuscan-sun_504/index.html" title="Under the Tuscan Sun">Under the Tuscan Sun</a></h3>,
#  <h3><a href="../../../a-summer-in-europe_458/index.html" title="A Summer In Europe">A Summer In Europe</a></h3>,
#  <h3><a href="../../../the-great-railway-bazaar_446/index.html" title="The Great Railway Bazaar">The Great Railway Bazaar</a></h3>,
#  <h3><a href="../../../a-year-in-provence-provence-1_421/index.html" title="A Year in Provence (Provence #1)">A Year in Provence ...</a></h3>,
#  <h3><a href="../../../the-road-to-little-dribbling-adventures-of-an-american-in-britain-notes-from-a-small-island-2_277/index.html" title="The Road to Little Dribbling: Adventures of an American in Britain (Notes From a Small Island #2)">The Road to Little ...</a></h3>,
#  <h3><a href="../../../neither-here-nor-there-travels-in-europe_198/index.html" title="Neither Here nor There: Travels in Europe">Neither Here nor There: ...</a></h3>,
#  <h3><a href="../../../1000-places-to-see-before-you-die_1/index.html" title="1,000 Places to See Before You Die">1,000 Places to See ...</a></h3>]

# %%
for ACC7004 in titles:
    print(ACC7004.get_text())
# Out:
# It's Only the Himalayas
# Full Moon over Noah’s ...
# See America: A Celebration ...
# Vagabonding: An Uncommon Guide ...
# Under the Tuscan Sun
# A Summer In Europe
# The Great Railway Bazaar
# A Year in Provence ...
# The Road to Little ...
# Neither Here nor There: ...
# 1,000 Places to See ...

# %% [markdown]
# # Accessing Word document

# %%
path = './DataFile' #path to the file

# %%
import os

# %%
os.chdir(path) # no need to execute if already done above; you can ignore the error message
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [70], line 1
# ----> 1 os.chdir(path)
#
# FileNotFoundError: [Errno 2] No such file or directory: './DataFile'

# %%
ls
# Out:
#  matches_England.json                SameCol2.csv      Test2.txt
#  MatrixPractice.dta                  SameCol3.csv      Test3.txt
# 'Microsoft 2020 Annual Report.pdf'   SameCol4.gz       Test_Doc.docx
# 'Microsoft 2021 Annual Report.pdf'   SameColFile.zip   Test_image.png
#  SameCol1.csv                        Test1.txt         Test_spreadsheet.xlsx

# %%
! pip install docx2txt
# Out:
# Collecting docx2txt
#   Downloading docx2txt-0.8.tar.gz (2.8 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: docx2txt
#   Building wheel for docx2txt (setup.py) ... done
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3960 sha256=a4510c6d81ae4ff3068de61a3421d78d8300b15aaedaf26122f67f03c240f9b8
#   Stored in directory: /home/jovyan/.cache/pip/wheels/40/75/01/e6c444034338bde9c7947d3467807f889123465c2371e77418
# Successfully built docx2txt
# Installing collected packages: docx2txt
# Successfully installed docx2txt-0.8

# %%
import docx2txt

# %%
result = docx2txt.process("Test_Doc.docx")

# %%
result
# Out:
# 'Date: 1/1/2020\n\nSubject: testing\n\nThis is to test the word document\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nGive me Word \n\n\n\nBelfast\n\n\n\nQueen’s University Belfast'

# %% [markdown]
# # Accessing Excel

# %%
! pip3 install openpyxl #if you are using Anaconda, install it differently without using pip
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 kB 6.5 MB/s eta 0:00:00a 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.10

# %%
import pandas as pd

# %%
df = pd.read_excel('Test_spreadsheet.xlsx', sheet_name = "Phones")

# %%
df
# Out:
#   Name  Address  Age   Phone
# 0  ABC  Belfast   25  Huawei
# 1  DEF   Dublin   30   Apple
# 2  MNO   London   40    Sony

# %% [markdown]
# # Accessing Stata file

# %%
path = './DataFile' #path to the file

# %%
import os

# %%
os.getcwd() # chdir
# Out:
# '/home/jovyan/DataFile'

# %%
import pandas as pd

# %%
ls
# Out:
#  matches_England.json                SameCol2.csv      Test2.txt
#  MatrixPractice.dta                  SameCol3.csv      Test3.txt
# 'Microsoft 2020 Annual Report.pdf'   SameCol4.gz       Test_Doc.docx
# 'Microsoft 2021 Annual Report.pdf'   SameColFile.zip   Test_image.png
#  SameCol1.csv                        Test1.txt         Test_spreadsheet.xlsx

# %%
df = pd.read_stata("MatrixPractice.dta")

# %%
df
# Out:
#     y  cons  x1  x2
# 0   1   1.0  40  25
# 1   2   1.0  45  20
# 2   1   1.0  38  30
# 3   3   1.0  50  30
# 4   2   1.0  48  28
# 5   3   1.0  55  30
# 6   3   1.0  53  34
# 7   4   1.0  55  36
# 8   4   1.0  58  32
# 9   3   1.0  40  34
# 10  5   1.0  55  38
# 11  3   1.0  48  28
# 12  3   1.0  45  30
# 13  2   1.0  55  36
# 14  4   1.0  60  34
# 15  5   1.0  60  38
# 16  5   1.0  60  42
# 17  5   1.0  65  38
# 18  4   1.0  50  34
# 19  3   1.0  58  38

# %% [markdown]
# # Accessing zipped files

# %% [markdown]
# # Zip files

# %%
path = './DataFile' #path to the file

# %%
import os
os.chdir(path) # no need to execute if already done above; you can ignore the error message
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [89], line 2
#       1 import os
# ----> 2 os.chdir(path)
#
# FileNotFoundError: [Errno 2] No such file or directory: './DataFile'

# %%
os.getcwd()
# Out:
# '/home/jovyan/DataFile'

# %%
from zipfile import ZipFile # import zipfile 
zf = ZipFile("SameColFile.zip") 
df3 = pd.read_csv(zf.open("SameCol1.csv"))

# %%
df3
# Out:
#   name address  phone
# 0    a     USA      5
# 1    b      UK      4
# 2    c     CAN      3

# %%
from zipfile import ZipFile
with ZipFile("SameColFile.zip", "r") as zip_ref:
   # Get list of files names in zip
   list_of_files2 = zip_ref.namelist()

# %%
list_of_files2
# Out:
# ['SameCol1.csv', 'SameCol2.csv', 'SameCol3.csv']

# %% [markdown]
# # GZIP files

# %%
df2 = pd.read_csv('SameCol4.gz', compression='gzip')

# %%
df2
# Out:
#    Unnamed: 0 name address  phone
# 0           0    a     USA      5
# 1           1    b      UK      4
# 2           2    c     CAN      3
